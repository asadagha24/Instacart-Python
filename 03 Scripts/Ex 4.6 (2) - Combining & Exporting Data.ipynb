# %% [markdown]
# ## 4.6 Merging & Exporting data (Part 2)

# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Import the data sets into Jupyter
# #### 2. Check the dimensions of the imported dataframes
# #### 3. Determine a suitable way to combine the orders_products_combined dataframe with the products data set¶
# #### 4. Confirm the results of the merge using the merge flag
# #### 5. Export the newly created dataframe as ords_prods_merge in a suitable format

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 1. Import the data sets into Jupyter

# %%
# Turn project folder path into a string.
path = '/Users/asadagha/Documents/CF Data Analytics/Data Analytics Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# Import dataset orders_products_combined.pkl
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Import dataset products_checked.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# ### 2. Check the dimensions of the imported dataframes

# %%
# Check the structure of the dataframe
df_ords_prods_combined.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 11)

# %%
# Check the structure of the dataframe
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Drop unnecessary columns
df_prods = df_prods.drop(['Unnamed: 0'], axis=1)

# %%
# Check the structure of the dataframe
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# ### 3. Determine a suitable way to combine the orders_products_combined dataframe with the products data set¶

# %%
# Merge the 'orders_prods_combined' dataframe with 'df_prods'
df_ords_prods_merge = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = 'merged_dataframes')

# %%
# drop the flag column '_merge' from the previous merge
df_ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  order_day_of_week  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 16)

# %% [markdown]
# ### 4. Confirm the results of the merge using the merge flag

# %%
df_ords_prods_merge['merged_dataframes'].value_counts()
# Out:
# merged_dataframes
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### 5. Export the newly created dataframe as ords_prods_merge in a suitable format

# %%
# Export data in pkl format
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
